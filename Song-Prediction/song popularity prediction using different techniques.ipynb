# %%
import warnings

warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from autoxgb import AutoXGB
from sklearn.ensemble import RandomForestClassifier
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.metrics import f1_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import QuantileTransformer

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0          212990.0      0.642286      0.856520  0.707073
# 1   1               NaN      0.054866      0.733289  0.835545
# 2   2          193213.0           NaN      0.188387  0.783524
# 3   3          249893.0      0.488660      0.585234  0.552685
# 4   4          165969.0      0.493017           NaN  0.740982
#
#    instrumentalness   key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002001  10.0       NaN -5.619088           0     0.082570
# 1          0.000996   8.0  0.436428 -5.236965           1     0.127358
# 2         -0.002694   5.0  0.170499 -4.951759           0     0.052282
# 3          0.000608   0.0  0.094805 -7.893694           0     0.035618
# 4          0.002033  10.0  0.094891 -2.684095           0     0.050746
#
#         tempo  time_signature  audio_valence  song_popularity
# 0  158.386236               4       0.734642                0
# 1  102.752988               3       0.711531                1
# 2  178.685791               3       0.425536                0
# 3  128.715630               3       0.453597                0
# 4  121.928157               4       0.741311                0

# %%
X = train.drop(["id", "song_popularity"], axis=1)
y = train.song_popularity

# %%
test_df = test.drop("id", 1)

# %%
# col_after transform
col_x = X.columns.to_list()

# %%
imp = IterativeImputer(max_iter=10)
X = imp.fit_transform(X)
x_test = imp.transform(test_df)

# %%
X
# Out:
# array([[2.12990000e+05, 6.42285517e-01, 8.56520289e-01, ...,
#         1.58386236e+02, 4.00000000e+00, 7.34641557e-01],
#        [1.97014838e+05, 5.48656388e-02, 7.33288830e-01, ...,
#         1.02752988e+02, 3.00000000e+00, 7.11530551e-01],
#        [1.93213000e+05, 1.59724777e-01, 1.88387099e-01, ...,
#         1.78685791e+02, 3.00000000e+00, 4.25536016e-01],
#        ...,
#        [1.60879000e+05, 8.77431248e-01, 4.09064592e-01, ...,
#         9.95560744e+01, 3.00000000e+00, 1.77947389e-01],
#        [1.93918000e+05, 1.73402378e-01, 3.65738206e-01, ...,
#         1.39857384e+02, 3.00000000e+00, 7.72978406e-01],
#        [1.96475000e+05, 7.11618441e-03, 3.54585290e-01, ...,
#         1.01974949e+02, 3.00000000e+00, 5.88549127e-01]])

# %%
x_test
# Out:
# array([[3.08523000e+05, 1.98453405e-02, 4.35637804e-01, ...,
#         1.26129304e+02, 4.00000000e+00, 3.99620451e-01],
#        [2.00011000e+05, 7.01191036e-02, 7.31256023e-01, ...,
#         8.64481489e+01, 3.00000000e+00, 4.99424461e-01],
#        [2.79758000e+05, 8.10637132e-01, 5.68857904e-01, ...,
#         9.95443512e+01, 3.00000000e+00, 5.64950591e-01],
#        ...,
#        [1.88434000e+05, 7.53472359e-01, 7.83946794e-01, ...,
#         1.19090558e+02, 4.00000000e+00, 4.82961338e-01],
#        [1.73044000e+05, 8.63578837e-01, 3.73283420e-01, ...,
#         1.03048349e+02, 3.00000000e+00, 5.18741779e-01],
#        [1.57896000e+05, 1.98523554e-02, 7.20380057e-01, ...,
#         1.09873611e+02, 4.00000000e+00, 9.71367981e-01]])

# %%
X = pd.DataFrame(columns=col_x, data=X)
X.head()
# Out:
#    song_duration_ms  acousticness  danceability    energy  instrumentalness  \
# 0     212990.000000      0.642286      0.856520  0.707073          0.002001
# 1     197014.838414      0.054866      0.733289  0.835545          0.000996
# 2     193213.000000      0.159725      0.188387  0.783524         -0.002694
# 3     249893.000000      0.488660      0.585234  0.552685          0.000608
# 4     165969.000000      0.493017      0.644204  0.740982          0.002033
#
#     key  liveness  loudness  audio_mode  speechiness       tempo  \
# 0  10.0  0.215368 -5.619088         0.0     0.082570  158.386236
# 1   8.0  0.436428 -5.236965         1.0     0.127358  102.752988
# 2   5.0  0.170499 -4.951759         0.0     0.052282  178.685791
# 3   0.0  0.094805 -7.893694         0.0     0.035618  128.715630
# 4  10.0  0.094891 -2.684095         0.0     0.050746  121.928157
#
#    time_signature  audio_valence
# 0             4.0       0.734642
# 1             3.0       0.711531
# 2             3.0       0.425536
# 3             3.0       0.453597
# 4             4.0       0.741311

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=42
)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred = rf.predict(X_test)
f1_score(y_test, pred)
# Out:
# 0.12269207861822513

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.95      0.77      2557
#            1       0.44      0.07      0.12      1443
#
#     accuracy                           0.63      4000
#    macro avg       0.54      0.51      0.44      4000
# weighted avg       0.57      0.63      0.53      4000

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, pred)
# Out:
# 0.5096824961901223

# %%
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    id  song_duration_ms  acousticness  danceability    energy  \
# 0   0          212990.0      0.642286      0.856520  0.707073
# 1   1               NaN      0.054866      0.733289  0.835545
# 2   2          193213.0           NaN      0.188387  0.783524
# 3   3          249893.0      0.488660      0.585234  0.552685
# 4   4          165969.0      0.493017           NaN  0.740982
#
#    instrumentalness   key  liveness  loudness  audio_mode  speechiness  \
# 0          0.002001  10.0       NaN -5.619088           0     0.082570
# 1          0.000996   8.0  0.436428 -5.236965           1     0.127358
# 2         -0.002694   5.0  0.170499 -4.951759           0     0.052282
# 3          0.000608   0.0  0.094805 -7.893694           0     0.035618
# 4          0.002033  10.0  0.094891 -2.684095           0     0.050746
#
#         tempo  time_signature  audio_valence  song_popularity
# 0  158.386236               4       0.734642                0
# 1  102.752988               3       0.711531                1
# 2  178.685791               3       0.425536                0
# 3  128.715630               3       0.453597                0
# 4  121.928157               4       0.741311                0

# %%
df.drop("id", axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# song_duration_ms    4101
# acousticness        3992
# danceability        4026
# energy              3975
# instrumentalness    3985
# key                 4065
# liveness            4086
# loudness            3957
# audio_mode             0
# speechiness            0
# tempo                  0
# time_signature         0
# audio_valence          0
# song_popularity        0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
lgr = make_pipeline(
    SimpleImputer(strategy="mean", add_indicator=True),
    StandardScaler(),
    LogisticRegression(random_state=0),
)

# %%
log_reg_scores = cross_val_score(lgr, X_train, y_train)

# %%
log_reg_scores
# Out:
# array([0.63444444, 0.63402778, 0.63430556, 0.635     , 0.63513889])

# %%
log_reg_scores.mean()
# Out:
# 0.6345833333333333

# %% [markdown]
# # Cross validation Strategies
#
# ## KFold

# %%
from sklearn.model_selection import KFold

cross_val_score(lgr, X_train, y_train, cv=KFold(n_splits=5)).mean()
# Out:
# 0.6346111111111111

# %% [markdown]
# # RepeatedFold

# %%
from sklearn.model_selection import RepeatedKFold

scores = cross_val_score(
    lgr, X_train, y_train, cv=RepeatedKFold(n_splits=5, n_repeats=3)
)

# %%
scores
# Out:
# array([0.62527778, 0.64333333, 0.63222222, 0.63902778, 0.63361111,
#        0.63638889, 0.63125   , 0.63236111, 0.64111111, 0.63236111,
#        0.63652778, 0.63805556, 0.63875   , 0.63152778, 0.62861111])

# %%
scores.shape
# Out:
# (15,)

# %%
scores.mean()
# Out:
# 0.6346944444444446

# %% [markdown]
# # RepeatedStratifiedKfold

# %%
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
scores = cross_val_score(
    lgr, X_train, y_train, cv=RepeatedStratifiedKFold(n_splits=5, n_repeats=3)
)

# %%
scores
# Out:
# array([0.635     , 0.63458333, 0.63486111, 0.63527778, 0.63375   ,
#        0.63333333, 0.63527778, 0.63388889, 0.63541667, 0.63472222,
#        0.63583333, 0.635     , 0.63472222, 0.63402778, 0.635     ])

# %%
scores.mean()
# Out:
# 0.634712962962963

# %% [markdown]
# # StratifiedShuffleSplit
#
# You will need to scale X

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler

# %%
sss = StratifiedShuffleSplit(n_splits=15, random_state=42)

# %%
# scale = StandardScaler()
# X = scale.fit_transform(X)

# %%
# for train_idx, test_idx in sss.split(X, y):
#     print("TRAIN:", train_idx, "TEST:", test_idx)
#     X_train, X_test = X[train_idx], X[test_idx]
#     y_train, y_test = y[train_idx], y[test_idx]

# %%
from sklearn.metrics import auc, roc_auc_score, roc_curve
from xgboost import XGBClassifier

# %%
sss = StratifiedShuffleSplit(n_splits=10, random_state=1234)

preds = []
scores = []
feature_importance_df = pd.DataFrame()
for fold, (idx_train, idx_valid) in enumerate(sss.split(X, y)):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

    model = XGBClassifier()
    model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
    pred_valid = model.predict_proba(X_valid)[:, 1]
    fpr, tpr, _ = roc_curve(y_valid, pred_valid)
    score = auc(fpr, tpr)
    scores.append(score)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = X.columns
    fold_importance_df["importance"] = model.feature_importances_
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat(
        [feature_importance_df, fold_importance_df], axis=0
    )

    print(f"Fold: {fold + 1} Score: {score}" "\n")
    print("||" * 40, "\n")

    test_preds = model.predict_proba(X_test)[:, 1]
    preds.append(test_preds)

print(f"Overall Validation Score: {np.mean(scores)}")
# Out:
# [01:20:28] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67258
# [1]	validation_0-logloss:0.66195
# [2]	validation_0-logloss:0.65538
# [3]	validation_0-logloss:0.65236
# [4]	validation_0-logloss:0.65030
# [5]	validation_0-logloss:0.64875
# [6]	validation_0-logloss:0.64942
# [7]	validation_0-logloss:0.64933
# [8]	validation_0-logloss:0.65042
# [9]	validation_0-logloss:0.64995
# [10]	validation_0-logloss:0.64945
# [11]	validation_0-logloss:0.64941
# [12]	validation_0-logloss:0.64968
# [13]	validation_0-logloss:0.64968
# [14]	validation_0-logloss:0.64977
# [15]	validation_0-logloss:0.64986
# [16]	validation_0-logloss:0.64989
# [17]	validation_0-logloss:0.65002
# [18]	validation_0-logloss:0.64960
# [19]	validation_0-logloss:0.64922
# [20]	validation_0-logloss:0.64923
# [21]	validation_0-logloss:0.64976
# [22]	validation_0-logloss:0.64990
# [23]	validation_0-logloss:0.65055
# [24]	validation_0-logloss:0.65073
# [25]	validation_0-logloss:0.65126
# [26]	validation_0-logloss:0.65128
# [27]	validation_0-logloss:0.65141
# [28]	validation_0-logloss:0.65137
# [29]	validation_0-logloss:0.65144
# [30]	validation_0-logloss:0.65192
# [31]	validation_0-logloss:0.65212
# [32]	validation_0-logloss:0.65231
# [33]	validation_0-logloss:0.65222
# [34]	validation_0-logloss:0.65278
# [35]	validation_0-logloss:0.65274
# [36]	validation_0-logloss:0.65267
# [37]	validation_0-logloss:0.65241
# [38]	validation_0-logloss:0.65272
# [39]	validation_0-logloss:0.65260
# [40]	validation_0-logloss:0.65241
# [41]	validation_0-logloss:0.65223
# [42]	validation_0-logloss:0.65298
# [43]	validation_0-logloss:0.65294
# [44]	validation_0-logloss:0.65298
# [45]	validation_0-logloss:0.65311
# [46]	validation_0-logloss:0.65341
# [47]	validation_0-logloss:0.65384
# [48]	validation_0-logloss:0.65409
# [49]	validation_0-logloss:0.65414
# [50]	validation_0-logloss:0.65447
# [51]	validation_0-logloss:0.65480
# [52]	validation_0-logloss:0.65522
# [53]	validation_0-logloss:0.65480
# [54]	validation_0-logloss:0.65534
# [55]	validation_0-logloss:0.65592
# [56]	validation_0-logloss:0.65605
# [57]	validation_0-logloss:0.65601
# [58]	validation_0-logloss:0.65590
# [59]	validation_0-logloss:0.65659
# [60]	validation_0-logloss:0.65663
# [61]	validation_0-logloss:0.65637
# [62]	validation_0-logloss:0.65632
# [63]	validation_0-logloss:0.65621
# [64]	validation_0-logloss:0.65621
# [65]	validation_0-logloss:0.65628
# [66]	validation_0-logloss:0.65670
# [67]	validation_0-logloss:0.65605
# [68]	validation_0-logloss:0.65581
# [69]	validation_0-logloss:0.65567
# [70]	validation_0-logloss:0.65492
# [71]	validation_0-logloss:0.65517
# [72]	validation_0-logloss:0.65513
# [73]	validation_0-logloss:0.65526
# [74]	validation_0-logloss:0.65528
# [75]	validation_0-logloss:0.65528
# [76]	validation_0-logloss:0.65499
# [77]	validation_0-logloss:0.65499
# [78]	validation_0-logloss:0.65476
# [79]	validation_0-logloss:0.65493
# [80]	validation_0-logloss:0.65480
# [81]	validation_0-logloss:0.65455
# [82]	validation_0-logloss:0.65509
# [83]	validation_0-logloss:0.65525
# [84]	validation_0-logloss:0.65526
# [85]	validation_0-logloss:0.65532
# [86]	validation_0-logloss:0.65527
# [87]	validation_0-logloss:0.65531
# [88]	validation_0-logloss:0.65485
# [89]	validation_0-logloss:0.65469
# [90]	validation_0-logloss:0.65472
# [91]	validation_0-logloss:0.65478
# [92]	validation_0-logloss:0.65490
# [93]	validation_0-logloss:0.65468
# [94]	validation_0-logloss:0.65478
# [95]	validation_0-logloss:0.65492
# [96]	validation_0-logloss:0.65533
# [97]	validation_0-logloss:0.65535
# [98]	validation_0-logloss:0.65532
# [99]	validation_0-logloss:0.65579
# Fold: 1 Score: 0.5760654475322133
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:20:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67196
# [1]	validation_0-logloss:0.66176
# [2]	validation_0-logloss:0.65561
# [3]	validation_0-logloss:0.65275
# [4]	validation_0-logloss:0.65176
# [5]	validation_0-logloss:0.65022
# [6]	validation_0-logloss:0.64944
# [7]	validation_0-logloss:0.64995
# [8]	validation_0-logloss:0.64946
# [9]	validation_0-logloss:0.64829
# [10]	validation_0-logloss:0.64800
# [11]	validation_0-logloss:0.64813
# [12]	validation_0-logloss:0.64914
# [13]	validation_0-logloss:0.64907
# [14]	validation_0-logloss:0.64911
# [15]	validation_0-logloss:0.64980
# [16]	validation_0-logloss:0.64978
# [17]	validation_0-logloss:0.65020
# [18]	validation_0-logloss:0.65056
# [19]	validation_0-logloss:0.65085
# [20]	validation_0-logloss:0.65103
# [21]	validation_0-logloss:0.65086
# [22]	validation_0-logloss:0.65094
# [23]	validation_0-logloss:0.65170
# [24]	validation_0-logloss:0.65165
# [25]	validation_0-logloss:0.65214
# [26]	validation_0-logloss:0.65214
# [27]	validation_0-logloss:0.65224
# [28]	validation_0-logloss:0.65213
# [29]	validation_0-logloss:0.65225
# [30]	validation_0-logloss:0.65154
# [31]	validation_0-logloss:0.65215
# [32]	validation_0-logloss:0.65331
# [33]	validation_0-logloss:0.65384
# [34]	validation_0-logloss:0.65382
# [35]	validation_0-logloss:0.65394
# [36]	validation_0-logloss:0.65379
# [37]	validation_0-logloss:0.65410
# [38]	validation_0-logloss:0.65414
# [39]	validation_0-logloss:0.65455
# [40]	validation_0-logloss:0.65500
# [41]	validation_0-logloss:0.65513
# [42]	validation_0-logloss:0.65523
# [43]	validation_0-logloss:0.65570
# [44]	validation_0-logloss:0.65538
# [45]	validation_0-logloss:0.65596
# [46]	validation_0-logloss:0.65598
# [47]	validation_0-logloss:0.65593
# [48]	validation_0-logloss:0.65606
# [49]	validation_0-logloss:0.65608
# [50]	validation_0-logloss:0.65643
# [51]	validation_0-logloss:0.65632
# [52]	validation_0-logloss:0.65628
# [53]	validation_0-logloss:0.65702
# [54]	validation_0-logloss:0.65742
# [55]	validation_0-logloss:0.65768
# [56]	validation_0-logloss:0.65765
# [57]	validation_0-logloss:0.65801
# [58]	validation_0-logloss:0.65816
# [59]	validation_0-logloss:0.65866
# [60]	validation_0-logloss:0.65869
# [61]	validation_0-logloss:0.65904
# [62]	validation_0-logloss:0.65857
# [63]	validation_0-logloss:0.65838
# [64]	validation_0-logloss:0.65861
# [65]	validation_0-logloss:0.65910
# [66]	validation_0-logloss:0.65910
# [67]	validation_0-logloss:0.65927
# [68]	validation_0-logloss:0.65902
# [69]	validation_0-logloss:0.65924
# [70]	validation_0-logloss:0.65902
# [71]	validation_0-logloss:0.65918
# [72]	validation_0-logloss:0.65911
# [73]	validation_0-logloss:0.65996
# [74]	validation_0-logloss:0.66046
# [75]	validation_0-logloss:0.66053
# [76]	validation_0-logloss:0.66085
# [77]	validation_0-logloss:0.66087
# [78]	validation_0-logloss:0.66112
# [79]	validation_0-logloss:0.66056
# [80]	validation_0-logloss:0.66056
# [81]	validation_0-logloss:0.66069
# [82]	validation_0-logloss:0.66116
# [83]	validation_0-logloss:0.66132
# [84]	validation_0-logloss:0.66148
# [85]	validation_0-logloss:0.66134
# [86]	validation_0-logloss:0.66187
# [87]	validation_0-logloss:0.66244
# [88]	validation_0-logloss:0.66253
# [89]	validation_0-logloss:0.66251
# [90]	validation_0-logloss:0.66290
# [91]	validation_0-logloss:0.66234
# [92]	validation_0-logloss:0.66239
# [93]	validation_0-logloss:0.66224
# [94]	validation_0-logloss:0.66265
# [95]	validation_0-logloss:0.66266
# [96]	validation_0-logloss:0.66261
# [97]	validation_0-logloss:0.66295
# [98]	validation_0-logloss:0.66317
# [99]	validation_0-logloss:0.66349
# Fold: 2 Score: 0.5646245948719941
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:20:46] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67131
# [1]	validation_0-logloss:0.66007
# [2]	validation_0-logloss:0.65401
# [3]	validation_0-logloss:0.65108
# [4]	validation_0-logloss:0.64954
# [5]	validation_0-logloss:0.64869
# [6]	validation_0-logloss:0.64773
# [7]	validation_0-logloss:0.64680
# [8]	validation_0-logloss:0.64656
# [9]	validation_0-logloss:0.64669
# [10]	validation_0-logloss:0.64681
# [11]	validation_0-logloss:0.64744
# [12]	validation_0-logloss:0.64758
# [13]	validation_0-logloss:0.64714
# [14]	validation_0-logloss:0.64763
# [15]	validation_0-logloss:0.64739
# [16]	validation_0-logloss:0.64724
# [17]	validation_0-logloss:0.64720
# [18]	validation_0-logloss:0.64709
# [19]	validation_0-logloss:0.64752
# [20]	validation_0-logloss:0.64766
# [21]	validation_0-logloss:0.64754
# [22]	validation_0-logloss:0.64777
# [23]	validation_0-logloss:0.64881
# [24]	validation_0-logloss:0.64854
# [25]	validation_0-logloss:0.64873
# [26]	validation_0-logloss:0.64893
# [27]	validation_0-logloss:0.64858
# [28]	validation_0-logloss:0.64866
# [29]	validation_0-logloss:0.64850
# [30]	validation_0-logloss:0.64857
# [31]	validation_0-logloss:0.64881
# [32]	validation_0-logloss:0.64874
# [33]	validation_0-logloss:0.64887
# [34]	validation_0-logloss:0.64937
# [35]	validation_0-logloss:0.64948
# [36]	validation_0-logloss:0.65014
# [37]	validation_0-logloss:0.65019
# [38]	validation_0-logloss:0.65082
# [39]	validation_0-logloss:0.65098
# [40]	validation_0-logloss:0.65099
# [41]	validation_0-logloss:0.65100
# [42]	validation_0-logloss:0.65107
# [43]	validation_0-logloss:0.65121
# [44]	validation_0-logloss:0.65151
# [45]	validation_0-logloss:0.65174
# [46]	validation_0-logloss:0.65181
# [47]	validation_0-logloss:0.65172
# [48]	validation_0-logloss:0.65198
# [49]	validation_0-logloss:0.65195
# [50]	validation_0-logloss:0.65240
# [51]	validation_0-logloss:0.65335
# [52]	validation_0-logloss:0.65352
# [53]	validation_0-logloss:0.65362
# [54]	validation_0-logloss:0.65358
# [55]	validation_0-logloss:0.65352
# [56]	validation_0-logloss:0.65347
# [57]	validation_0-logloss:0.65365
# [58]	validation_0-logloss:0.65387
# [59]	validation_0-logloss:0.65401
# [60]	validation_0-logloss:0.65424
# [61]	validation_0-logloss:0.65487
# [62]	validation_0-logloss:0.65570
# [63]	validation_0-logloss:0.65526
# [64]	validation_0-logloss:0.65593
# [65]	validation_0-logloss:0.65592
# [66]	validation_0-logloss:0.65596
# [67]	validation_0-logloss:0.65650
# [68]	validation_0-logloss:0.65645
# [69]	validation_0-logloss:0.65665
# [70]	validation_0-logloss:0.65709
# [71]	validation_0-logloss:0.65734
# [72]	validation_0-logloss:0.65776
# [73]	validation_0-logloss:0.65805
# [74]	validation_0-logloss:0.65812
# [75]	validation_0-logloss:0.65850
# [76]	validation_0-logloss:0.65851
# [77]	validation_0-logloss:0.65859
# [78]	validation_0-logloss:0.65848
# [79]	validation_0-logloss:0.65842
# [80]	validation_0-logloss:0.65832
# [81]	validation_0-logloss:0.65829
# [82]	validation_0-logloss:0.65823
# [83]	validation_0-logloss:0.65839
# [84]	validation_0-logloss:0.65843
# [85]	validation_0-logloss:0.65835
# [86]	validation_0-logloss:0.65756
# [87]	validation_0-logloss:0.65739
# [88]	validation_0-logloss:0.65756
# [89]	validation_0-logloss:0.65807
# [90]	validation_0-logloss:0.65821
# [91]	validation_0-logloss:0.65816
# [92]	validation_0-logloss:0.65823
# [93]	validation_0-logloss:0.65815
# [94]	validation_0-logloss:0.65829
# [95]	validation_0-logloss:0.65887
# [96]	validation_0-logloss:0.65909
# [97]	validation_0-logloss:0.65913
# [98]	validation_0-logloss:0.65890
# [99]	validation_0-logloss:0.65898
# Fold: 3 Score: 0.5667984985305847
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:20:56] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67122
# [1]	validation_0-logloss:0.66053
# [2]	validation_0-logloss:0.65402
# [3]	validation_0-logloss:0.65121
# [4]	validation_0-logloss:0.64946
# [5]	validation_0-logloss:0.64839
# [6]	validation_0-logloss:0.64838
# [7]	validation_0-logloss:0.64775
# [8]	validation_0-logloss:0.64779
# [9]	validation_0-logloss:0.64808
# [10]	validation_0-logloss:0.64864
# [11]	validation_0-logloss:0.64874
# [12]	validation_0-logloss:0.64903
# [13]	validation_0-logloss:0.64827
# [14]	validation_0-logloss:0.64898
# [15]	validation_0-logloss:0.64891
# [16]	validation_0-logloss:0.64933
# [17]	validation_0-logloss:0.64965
# [18]	validation_0-logloss:0.64981
# [19]	validation_0-logloss:0.65011
# [20]	validation_0-logloss:0.64987
# [21]	validation_0-logloss:0.65011
# [22]	validation_0-logloss:0.64978
# [23]	validation_0-logloss:0.65005
# [24]	validation_0-logloss:0.65019
# [25]	validation_0-logloss:0.65029
# [26]	validation_0-logloss:0.65007
# [27]	validation_0-logloss:0.65054
# [28]	validation_0-logloss:0.65056
# [29]	validation_0-logloss:0.65104
# [30]	validation_0-logloss:0.65113
# [31]	validation_0-logloss:0.65093
# [32]	validation_0-logloss:0.65173
# [33]	validation_0-logloss:0.65165
# [34]	validation_0-logloss:0.65214
# [35]	validation_0-logloss:0.65268
# [36]	validation_0-logloss:0.65333
# [37]	validation_0-logloss:0.65320
# [38]	validation_0-logloss:0.65325
# [39]	validation_0-logloss:0.65321
# [40]	validation_0-logloss:0.65326
# [41]	validation_0-logloss:0.65308
# [42]	validation_0-logloss:0.65335
# [43]	validation_0-logloss:0.65295
# [44]	validation_0-logloss:0.65315
# [45]	validation_0-logloss:0.65378
# [46]	validation_0-logloss:0.65414
# [47]	validation_0-logloss:0.65481
# [48]	validation_0-logloss:0.65555
# [49]	validation_0-logloss:0.65574
# [50]	validation_0-logloss:0.65616
# [51]	validation_0-logloss:0.65637
# [52]	validation_0-logloss:0.65690
# [53]	validation_0-logloss:0.65746
# [54]	validation_0-logloss:0.65807
# [55]	validation_0-logloss:0.65823
# [56]	validation_0-logloss:0.65839
# [57]	validation_0-logloss:0.65855
# [58]	validation_0-logloss:0.65884
# [59]	validation_0-logloss:0.65886
# [60]	validation_0-logloss:0.65890
# [61]	validation_0-logloss:0.65933
# [62]	validation_0-logloss:0.65933
# [63]	validation_0-logloss:0.66012
# [64]	validation_0-logloss:0.66058
# [65]	validation_0-logloss:0.66058
# [66]	validation_0-logloss:0.66054
# [67]	validation_0-logloss:0.66060
# [68]	validation_0-logloss:0.66071
# [69]	validation_0-logloss:0.66137
# [70]	validation_0-logloss:0.66135
# [71]	validation_0-logloss:0.66159
# [72]	validation_0-logloss:0.66159
# [73]	validation_0-logloss:0.66185
# [74]	validation_0-logloss:0.66247
# [75]	validation_0-logloss:0.66268
# [76]	validation_0-logloss:0.66333
# [77]	validation_0-logloss:0.66366
# [78]	validation_0-logloss:0.66375
# [79]	validation_0-logloss:0.66382
# [80]	validation_0-logloss:0.66379
# [81]	validation_0-logloss:0.66385
# [82]	validation_0-logloss:0.66385
# [83]	validation_0-logloss:0.66380
# [84]	validation_0-logloss:0.66400
# [85]	validation_0-logloss:0.66427
# [86]	validation_0-logloss:0.66413
# [87]	validation_0-logloss:0.66474
# [88]	validation_0-logloss:0.66486
# [89]	validation_0-logloss:0.66508
# [90]	validation_0-logloss:0.66540
# [91]	validation_0-logloss:0.66571
# [92]	validation_0-logloss:0.66574
# [93]	validation_0-logloss:0.66632
# [94]	validation_0-logloss:0.66624
# [95]	validation_0-logloss:0.66622
# [96]	validation_0-logloss:0.66640
# [97]	validation_0-logloss:0.66615
# [98]	validation_0-logloss:0.66655
# [99]	validation_0-logloss:0.66694
# Fold: 4 Score: 0.5582520918797399
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:21:06] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67219
# [1]	validation_0-logloss:0.66228
# [2]	validation_0-logloss:0.65699
# [3]	validation_0-logloss:0.65369
# [4]	validation_0-logloss:0.65222
# [5]	validation_0-logloss:0.65108
# [6]	validation_0-logloss:0.65073
# [7]	validation_0-logloss:0.65029
# [8]	validation_0-logloss:0.65028
# [9]	validation_0-logloss:0.65027
# [10]	validation_0-logloss:0.64992
# [11]	validation_0-logloss:0.64988
# [12]	validation_0-logloss:0.65114
# [13]	validation_0-logloss:0.65117
# [14]	validation_0-logloss:0.65149
# [15]	validation_0-logloss:0.65124
# [16]	validation_0-logloss:0.65149
# [17]	validation_0-logloss:0.65150
# [18]	validation_0-logloss:0.65121
# [19]	validation_0-logloss:0.65168
# [20]	validation_0-logloss:0.65172
# [21]	validation_0-logloss:0.65202
# [22]	validation_0-logloss:0.65211
# [23]	validation_0-logloss:0.65180
# [24]	validation_0-logloss:0.65256
# [25]	validation_0-logloss:0.65263
# [26]	validation_0-logloss:0.65289
# [27]	validation_0-logloss:0.65321
# [28]	validation_0-logloss:0.65320
# [29]	validation_0-logloss:0.65377
# [30]	validation_0-logloss:0.65455
# [31]	validation_0-logloss:0.65462
# [32]	validation_0-logloss:0.65453
# [33]	validation_0-logloss:0.65509
# [34]	validation_0-logloss:0.65478
# [35]	validation_0-logloss:0.65461
# [36]	validation_0-logloss:0.65470
# [37]	validation_0-logloss:0.65469
# [38]	validation_0-logloss:0.65504
# [39]	validation_0-logloss:0.65559
# [40]	validation_0-logloss:0.65574
# [41]	validation_0-logloss:0.65582
# [42]	validation_0-logloss:0.65674
# [43]	validation_0-logloss:0.65692
# [44]	validation_0-logloss:0.65720
# [45]	validation_0-logloss:0.65743
# [46]	validation_0-logloss:0.65743
# [47]	validation_0-logloss:0.65757
# [48]	validation_0-logloss:0.65728
# [49]	validation_0-logloss:0.65762
# [50]	validation_0-logloss:0.65777
# [51]	validation_0-logloss:0.65819
# [52]	validation_0-logloss:0.65787
# [53]	validation_0-logloss:0.65748
# [54]	validation_0-logloss:0.65763
# [55]	validation_0-logloss:0.65765
# [56]	validation_0-logloss:0.65783
# [57]	validation_0-logloss:0.65846
# [58]	validation_0-logloss:0.65866
# [59]	validation_0-logloss:0.65883
# [60]	validation_0-logloss:0.65919
# [61]	validation_0-logloss:0.65942
# [62]	validation_0-logloss:0.65942
# [63]	validation_0-logloss:0.65971
# [64]	validation_0-logloss:0.65951
# [65]	validation_0-logloss:0.65960
# [66]	validation_0-logloss:0.65949
# [67]	validation_0-logloss:0.65936
# [68]	validation_0-logloss:0.65958
# [69]	validation_0-logloss:0.66017
# [70]	validation_0-logloss:0.65983
# [71]	validation_0-logloss:0.65976
# [72]	validation_0-logloss:0.66008
# [73]	validation_0-logloss:0.66002
# [74]	validation_0-logloss:0.66008
# [75]	validation_0-logloss:0.66053
# [76]	validation_0-logloss:0.66052
# [77]	validation_0-logloss:0.66058
# [78]	validation_0-logloss:0.66049
# [79]	validation_0-logloss:0.65999
# [80]	validation_0-logloss:0.66005
# [81]	validation_0-logloss:0.66008
# [82]	validation_0-logloss:0.66009
# [83]	validation_0-logloss:0.66015
# [84]	validation_0-logloss:0.66025
# [85]	validation_0-logloss:0.66037
# [86]	validation_0-logloss:0.66097
# [87]	validation_0-logloss:0.66115
# [88]	validation_0-logloss:0.66151
# [89]	validation_0-logloss:0.66113
# [90]	validation_0-logloss:0.66149
# [91]	validation_0-logloss:0.66213
# [92]	validation_0-logloss:0.66260
# [93]	validation_0-logloss:0.66304
# [94]	validation_0-logloss:0.66298
# [95]	validation_0-logloss:0.66328
# [96]	validation_0-logloss:0.66373
# [97]	validation_0-logloss:0.66413
# [98]	validation_0-logloss:0.66422
# [99]	validation_0-logloss:0.66467
# Fold: 5 Score: 0.5595609669756594
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:21:20] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67255
# [1]	validation_0-logloss:0.66263
# [2]	validation_0-logloss:0.65661
# [3]	validation_0-logloss:0.65421
# [4]	validation_0-logloss:0.65244
# [5]	validation_0-logloss:0.65249
# [6]	validation_0-logloss:0.65227
# [7]	validation_0-logloss:0.65187
# [8]	validation_0-logloss:0.65152
# [9]	validation_0-logloss:0.65134
# [10]	validation_0-logloss:0.65127
# [11]	validation_0-logloss:0.65149
# [12]	validation_0-logloss:0.65169
# [13]	validation_0-logloss:0.65174
# [14]	validation_0-logloss:0.65186
# [15]	validation_0-logloss:0.65257
# [16]	validation_0-logloss:0.65256
# [17]	validation_0-logloss:0.65262
# [18]	validation_0-logloss:0.65313
# [19]	validation_0-logloss:0.65285
# [20]	validation_0-logloss:0.65321
# [21]	validation_0-logloss:0.65327
# [22]	validation_0-logloss:0.65338
# [23]	validation_0-logloss:0.65331
# [24]	validation_0-logloss:0.65320
# [25]	validation_0-logloss:0.65329
# [26]	validation_0-logloss:0.65301
# [27]	validation_0-logloss:0.65381
# [28]	validation_0-logloss:0.65348
# [29]	validation_0-logloss:0.65366
# [30]	validation_0-logloss:0.65403
# [31]	validation_0-logloss:0.65390
# [32]	validation_0-logloss:0.65434
# [33]	validation_0-logloss:0.65492
# [34]	validation_0-logloss:0.65506
# [35]	validation_0-logloss:0.65391
# [36]	validation_0-logloss:0.65432
# [37]	validation_0-logloss:0.65447
# [38]	validation_0-logloss:0.65510
# [39]	validation_0-logloss:0.65516
# [40]	validation_0-logloss:0.65551
# [41]	validation_0-logloss:0.65559
# [42]	validation_0-logloss:0.65582
# [43]	validation_0-logloss:0.65594
# [44]	validation_0-logloss:0.65625
# [45]	validation_0-logloss:0.65604
# [46]	validation_0-logloss:0.65615
# [47]	validation_0-logloss:0.65622
# [48]	validation_0-logloss:0.65613
# [49]	validation_0-logloss:0.65632
# [50]	validation_0-logloss:0.65653
# [51]	validation_0-logloss:0.65647
# [52]	validation_0-logloss:0.65606
# [53]	validation_0-logloss:0.65567
# [54]	validation_0-logloss:0.65553
# [55]	validation_0-logloss:0.65623
# [56]	validation_0-logloss:0.65669
# [57]	validation_0-logloss:0.65695
# [58]	validation_0-logloss:0.65722
# [59]	validation_0-logloss:0.65731
# [60]	validation_0-logloss:0.65784
# [61]	validation_0-logloss:0.65809
# [62]	validation_0-logloss:0.65847
# [63]	validation_0-logloss:0.65845
# [64]	validation_0-logloss:0.65840
# [65]	validation_0-logloss:0.65865
# [66]	validation_0-logloss:0.65879
# [67]	validation_0-logloss:0.65909
# [68]	validation_0-logloss:0.65890
# [69]	validation_0-logloss:0.65847
# [70]	validation_0-logloss:0.65882
# [71]	validation_0-logloss:0.65882
# [72]	validation_0-logloss:0.65886
# [73]	validation_0-logloss:0.65889
# [74]	validation_0-logloss:0.65929
# [75]	validation_0-logloss:0.65888
# [76]	validation_0-logloss:0.65897
# [77]	validation_0-logloss:0.65931
# [78]	validation_0-logloss:0.65940
# [79]	validation_0-logloss:0.65973
# [80]	validation_0-logloss:0.65982
# [81]	validation_0-logloss:0.66060
# [82]	validation_0-logloss:0.66100
# [83]	validation_0-logloss:0.66160
# [84]	validation_0-logloss:0.66192
# [85]	validation_0-logloss:0.66192
# [86]	validation_0-logloss:0.66238
# [87]	validation_0-logloss:0.66234
# [88]	validation_0-logloss:0.66223
# [89]	validation_0-logloss:0.66233
# [90]	validation_0-logloss:0.66225
# [91]	validation_0-logloss:0.66229
# [92]	validation_0-logloss:0.66257
# [93]	validation_0-logloss:0.66267
# [94]	validation_0-logloss:0.66292
# [95]	validation_0-logloss:0.66343
# [96]	validation_0-logloss:0.66336
# [97]	validation_0-logloss:0.66421
# [98]	validation_0-logloss:0.66426
# [99]	validation_0-logloss:0.66453
# Fold: 6 Score: 0.5570214632851227
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:21:33] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67274
# [1]	validation_0-logloss:0.66334
# [2]	validation_0-logloss:0.65857
# [3]	validation_0-logloss:0.65565
# [4]	validation_0-logloss:0.65440
# [5]	validation_0-logloss:0.65402
# [6]	validation_0-logloss:0.65352
# [7]	validation_0-logloss:0.65408
# [8]	validation_0-logloss:0.65476
# [9]	validation_0-logloss:0.65551
# [10]	validation_0-logloss:0.65629
# [11]	validation_0-logloss:0.65642
# [12]	validation_0-logloss:0.65746
# [13]	validation_0-logloss:0.65738
# [14]	validation_0-logloss:0.65756
# [15]	validation_0-logloss:0.65816
# [16]	validation_0-logloss:0.65821
# [17]	validation_0-logloss:0.65851
# [18]	validation_0-logloss:0.65943
# [19]	validation_0-logloss:0.65972
# [20]	validation_0-logloss:0.65966
# [21]	validation_0-logloss:0.65987
# [22]	validation_0-logloss:0.65980
# [23]	validation_0-logloss:0.66012
# [24]	validation_0-logloss:0.66010
# [25]	validation_0-logloss:0.66058
# [26]	validation_0-logloss:0.66102
# [27]	validation_0-logloss:0.66060
# [28]	validation_0-logloss:0.66115
# [29]	validation_0-logloss:0.66174
# [30]	validation_0-logloss:0.66237
# [31]	validation_0-logloss:0.66296
# [32]	validation_0-logloss:0.66299
# [33]	validation_0-logloss:0.66287
# [34]	validation_0-logloss:0.66339
# [35]	validation_0-logloss:0.66337
# [36]	validation_0-logloss:0.66333
# [37]	validation_0-logloss:0.66331
# [38]	validation_0-logloss:0.66392
# [39]	validation_0-logloss:0.66453
# [40]	validation_0-logloss:0.66502
# [41]	validation_0-logloss:0.66487
# [42]	validation_0-logloss:0.66503
# [43]	validation_0-logloss:0.66506
# [44]	validation_0-logloss:0.66504
# [45]	validation_0-logloss:0.66536
# [46]	validation_0-logloss:0.66597
# [47]	validation_0-logloss:0.66600
# [48]	validation_0-logloss:0.66607
# [49]	validation_0-logloss:0.66612
# [50]	validation_0-logloss:0.66606
# [51]	validation_0-logloss:0.66611
# [52]	validation_0-logloss:0.66684
# [53]	validation_0-logloss:0.66709
# [54]	validation_0-logloss:0.66704
# [55]	validation_0-logloss:0.66698
# [56]	validation_0-logloss:0.66758
# [57]	validation_0-logloss:0.66767
# [58]	validation_0-logloss:0.66783
# [59]	validation_0-logloss:0.66814
# [60]	validation_0-logloss:0.66873
# [61]	validation_0-logloss:0.66917
# [62]	validation_0-logloss:0.66956
# [63]	validation_0-logloss:0.66938
# [64]	validation_0-logloss:0.66936
# [65]	validation_0-logloss:0.66941
# [66]	validation_0-logloss:0.66943
# [67]	validation_0-logloss:0.67002
# [68]	validation_0-logloss:0.67017
# [69]	validation_0-logloss:0.67068
# [70]	validation_0-logloss:0.67070
# [71]	validation_0-logloss:0.67084
# [72]	validation_0-logloss:0.67129
# [73]	validation_0-logloss:0.67123
# [74]	validation_0-logloss:0.67119
# [75]	validation_0-logloss:0.67171
# [76]	validation_0-logloss:0.67187
# [77]	validation_0-logloss:0.67230
# [78]	validation_0-logloss:0.67271
# [79]	validation_0-logloss:0.67320
# [80]	validation_0-logloss:0.67324
# [81]	validation_0-logloss:0.67352
# [82]	validation_0-logloss:0.67358
# [83]	validation_0-logloss:0.67400
# [84]	validation_0-logloss:0.67391
# [85]	validation_0-logloss:0.67431
# [86]	validation_0-logloss:0.67425
# [87]	validation_0-logloss:0.67471
# [88]	validation_0-logloss:0.67451
# [89]	validation_0-logloss:0.67491
# [90]	validation_0-logloss:0.67502
# [91]	validation_0-logloss:0.67541
# [92]	validation_0-logloss:0.67528
# [93]	validation_0-logloss:0.67571
# [94]	validation_0-logloss:0.67564
# [95]	validation_0-logloss:0.67593
# [96]	validation_0-logloss:0.67662
# [97]	validation_0-logloss:0.67658
# [98]	validation_0-logloss:0.67717
# [99]	validation_0-logloss:0.67749
# Fold: 7 Score: 0.5315371174420626
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:21:44] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67266
# [1]	validation_0-logloss:0.66196
# [2]	validation_0-logloss:0.65653
# [3]	validation_0-logloss:0.65393
# [4]	validation_0-logloss:0.65235
# [5]	validation_0-logloss:0.65251
# [6]	validation_0-logloss:0.65262
# [7]	validation_0-logloss:0.65338
# [8]	validation_0-logloss:0.65346
# [9]	validation_0-logloss:0.65330
# [10]	validation_0-logloss:0.65351
# [11]	validation_0-logloss:0.65357
# [12]	validation_0-logloss:0.65426
# [13]	validation_0-logloss:0.65446
# [14]	validation_0-logloss:0.65473
# [15]	validation_0-logloss:0.65483
# [16]	validation_0-logloss:0.65478
# [17]	validation_0-logloss:0.65482
# [18]	validation_0-logloss:0.65484
# [19]	validation_0-logloss:0.65514
# [20]	validation_0-logloss:0.65531
# [21]	validation_0-logloss:0.65531
# [22]	validation_0-logloss:0.65508
# [23]	validation_0-logloss:0.65535
# [24]	validation_0-logloss:0.65569
# [25]	validation_0-logloss:0.65568
# [26]	validation_0-logloss:0.65579
# [27]	validation_0-logloss:0.65596
# [28]	validation_0-logloss:0.65598
# [29]	validation_0-logloss:0.65585
# [30]	validation_0-logloss:0.65595
# [31]	validation_0-logloss:0.65635
# [32]	validation_0-logloss:0.65638
# [33]	validation_0-logloss:0.65657
# [34]	validation_0-logloss:0.65697
# [35]	validation_0-logloss:0.65671
# [36]	validation_0-logloss:0.65719
# [37]	validation_0-logloss:0.65699
# [38]	validation_0-logloss:0.65751
# [39]	validation_0-logloss:0.65780
# [40]	validation_0-logloss:0.65841
# [41]	validation_0-logloss:0.65848
# [42]	validation_0-logloss:0.65856
# [43]	validation_0-logloss:0.65943
# [44]	validation_0-logloss:0.65994
# [45]	validation_0-logloss:0.66011
# [46]	validation_0-logloss:0.66021
# [47]	validation_0-logloss:0.66051
# [48]	validation_0-logloss:0.66056
# [49]	validation_0-logloss:0.66117
# [50]	validation_0-logloss:0.66152
# [51]	validation_0-logloss:0.66139
# [52]	validation_0-logloss:0.66236
# [53]	validation_0-logloss:0.66221
# [54]	validation_0-logloss:0.66230
# [55]	validation_0-logloss:0.66247
# [56]	validation_0-logloss:0.66260
# [57]	validation_0-logloss:0.66311
# [58]	validation_0-logloss:0.66295
# [59]	validation_0-logloss:0.66336
# [60]	validation_0-logloss:0.66335
# [61]	validation_0-logloss:0.66346
# [62]	validation_0-logloss:0.66343
# [63]	validation_0-logloss:0.66306
# [64]	validation_0-logloss:0.66325
# [65]	validation_0-logloss:0.66439
# [66]	validation_0-logloss:0.66455
# [67]	validation_0-logloss:0.66530
# [68]	validation_0-logloss:0.66544
# [69]	validation_0-logloss:0.66591
# [70]	validation_0-logloss:0.66593
# [71]	validation_0-logloss:0.66590
# [72]	validation_0-logloss:0.66577
# [73]	validation_0-logloss:0.66658
# [74]	validation_0-logloss:0.66682
# [75]	validation_0-logloss:0.66688
# [76]	validation_0-logloss:0.66680
# [77]	validation_0-logloss:0.66664
# [78]	validation_0-logloss:0.66663
# [79]	validation_0-logloss:0.66661
# [80]	validation_0-logloss:0.66648
# [81]	validation_0-logloss:0.66651
# [82]	validation_0-logloss:0.66651
# [83]	validation_0-logloss:0.66729
# [84]	validation_0-logloss:0.66744
# [85]	validation_0-logloss:0.66700
# [86]	validation_0-logloss:0.66743
# [87]	validation_0-logloss:0.66810
# [88]	validation_0-logloss:0.66810
# [89]	validation_0-logloss:0.66821
# [90]	validation_0-logloss:0.66827
# [91]	validation_0-logloss:0.66859
# [92]	validation_0-logloss:0.66890
# [93]	validation_0-logloss:0.66900
# [94]	validation_0-logloss:0.66897
# [95]	validation_0-logloss:0.66904
# [96]	validation_0-logloss:0.66900
# [97]	validation_0-logloss:0.66936
# [98]	validation_0-logloss:0.66957
# [99]	validation_0-logloss:0.67010
# Fold: 8 Score: 0.5461009498585627
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:21:54] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67243
# [1]	validation_0-logloss:0.66106
# [2]	validation_0-logloss:0.65532
# [3]	validation_0-logloss:0.65260
# [4]	validation_0-logloss:0.65163
# [5]	validation_0-logloss:0.65112
# [6]	validation_0-logloss:0.65060
# [7]	validation_0-logloss:0.65029
# [8]	validation_0-logloss:0.65055
# [9]	validation_0-logloss:0.65047
# [10]	validation_0-logloss:0.65092
# [11]	validation_0-logloss:0.65065
# [12]	validation_0-logloss:0.65117
# [13]	validation_0-logloss:0.65153
# [14]	validation_0-logloss:0.65198
# [15]	validation_0-logloss:0.65280
# [16]	validation_0-logloss:0.65306
# [17]	validation_0-logloss:0.65309
# [18]	validation_0-logloss:0.65328
# [19]	validation_0-logloss:0.65352
# [20]	validation_0-logloss:0.65349
# [21]	validation_0-logloss:0.65356
# [22]	validation_0-logloss:0.65320
# [23]	validation_0-logloss:0.65333
# [24]	validation_0-logloss:0.65473
# [25]	validation_0-logloss:0.65479
# [26]	validation_0-logloss:0.65473
# [27]	validation_0-logloss:0.65511
# [28]	validation_0-logloss:0.65502
# [29]	validation_0-logloss:0.65477
# [30]	validation_0-logloss:0.65469
# [31]	validation_0-logloss:0.65485
# [32]	validation_0-logloss:0.65529
# [33]	validation_0-logloss:0.65541
# [34]	validation_0-logloss:0.65550
# [35]	validation_0-logloss:0.65583
# [36]	validation_0-logloss:0.65663
# [37]	validation_0-logloss:0.65722
# [38]	validation_0-logloss:0.65657
# [39]	validation_0-logloss:0.65633
# [40]	validation_0-logloss:0.65661
# [41]	validation_0-logloss:0.65660
# [42]	validation_0-logloss:0.65665
# [43]	validation_0-logloss:0.65723
# [44]	validation_0-logloss:0.65769
# [45]	validation_0-logloss:0.65769
# [46]	validation_0-logloss:0.65810
# [47]	validation_0-logloss:0.65836
# [48]	validation_0-logloss:0.65877
# [49]	validation_0-logloss:0.65914
# [50]	validation_0-logloss:0.65890
# [51]	validation_0-logloss:0.65909
# [52]	validation_0-logloss:0.65982
# [53]	validation_0-logloss:0.65980
# [54]	validation_0-logloss:0.66024
# [55]	validation_0-logloss:0.65973
# [56]	validation_0-logloss:0.65996
# [57]	validation_0-logloss:0.66002
# [58]	validation_0-logloss:0.66017
# [59]	validation_0-logloss:0.66031
# [60]	validation_0-logloss:0.66065
# [61]	validation_0-logloss:0.66100
# [62]	validation_0-logloss:0.66074
# [63]	validation_0-logloss:0.66072
# [64]	validation_0-logloss:0.66034
# [65]	validation_0-logloss:0.66079
# [66]	validation_0-logloss:0.66095
# [67]	validation_0-logloss:0.66169
# [68]	validation_0-logloss:0.66138
# [69]	validation_0-logloss:0.66136
# [70]	validation_0-logloss:0.66121
# [71]	validation_0-logloss:0.66094
# [72]	validation_0-logloss:0.66098
# [73]	validation_0-logloss:0.66087
# [74]	validation_0-logloss:0.66108
# [75]	validation_0-logloss:0.66128
# [76]	validation_0-logloss:0.66127
# [77]	validation_0-logloss:0.66095
# [78]	validation_0-logloss:0.66161
# [79]	validation_0-logloss:0.66175
# [80]	validation_0-logloss:0.66216
# [81]	validation_0-logloss:0.66209
# [82]	validation_0-logloss:0.66225
# [83]	validation_0-logloss:0.66266
# [84]	validation_0-logloss:0.66265
# [85]	validation_0-logloss:0.66256
# [86]	validation_0-logloss:0.66309
# [87]	validation_0-logloss:0.66327
# [88]	validation_0-logloss:0.66345
# [89]	validation_0-logloss:0.66366
# [90]	validation_0-logloss:0.66395
# [91]	validation_0-logloss:0.66431
# [92]	validation_0-logloss:0.66460
# [93]	validation_0-logloss:0.66442
# [94]	validation_0-logloss:0.66432
# [95]	validation_0-logloss:0.66448
# [96]	validation_0-logloss:0.66477
# [97]	validation_0-logloss:0.66488
# [98]	validation_0-logloss:0.66513
# [99]	validation_0-logloss:0.66479
# Fold: 9 Score: 0.5596000902263105
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:22:05] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.67036
# [1]	validation_0-logloss:0.65985
# [2]	validation_0-logloss:0.65443
# [3]	validation_0-logloss:0.65169
# [4]	validation_0-logloss:0.64950
# [5]	validation_0-logloss:0.64874
# [6]	validation_0-logloss:0.64916
# [7]	validation_0-logloss:0.64955
# [8]	validation_0-logloss:0.64987
# [9]	validation_0-logloss:0.65011
# [10]	validation_0-logloss:0.65002
# [11]	validation_0-logloss:0.64985
# [12]	validation_0-logloss:0.64962
# [13]	validation_0-logloss:0.65014
# [14]	validation_0-logloss:0.65058
# [15]	validation_0-logloss:0.65055
# [16]	validation_0-logloss:0.65096
# [17]	validation_0-logloss:0.65136
# [18]	validation_0-logloss:0.65129
# [19]	validation_0-logloss:0.65127
# [20]	validation_0-logloss:0.65146
# [21]	validation_0-logloss:0.65112
# [22]	validation_0-logloss:0.65212
# [23]	validation_0-logloss:0.65274
# [24]	validation_0-logloss:0.65301
# [25]	validation_0-logloss:0.65332
# [26]	validation_0-logloss:0.65362
# [27]	validation_0-logloss:0.65387
# [28]	validation_0-logloss:0.65378
# [29]	validation_0-logloss:0.65437
# [30]	validation_0-logloss:0.65416
# [31]	validation_0-logloss:0.65410
# [32]	validation_0-logloss:0.65434
# [33]	validation_0-logloss:0.65451
# [34]	validation_0-logloss:0.65413
# [35]	validation_0-logloss:0.65409
# [36]	validation_0-logloss:0.65492
# [37]	validation_0-logloss:0.65497
# [38]	validation_0-logloss:0.65481
# [39]	validation_0-logloss:0.65451
# [40]	validation_0-logloss:0.65621
# [41]	validation_0-logloss:0.65607
# [42]	validation_0-logloss:0.65630
# [43]	validation_0-logloss:0.65663
# [44]	validation_0-logloss:0.65659
# [45]	validation_0-logloss:0.65689
# [46]	validation_0-logloss:0.65664
# [47]	validation_0-logloss:0.65654
# [48]	validation_0-logloss:0.65688
# [49]	validation_0-logloss:0.65738
# [50]	validation_0-logloss:0.65757
# [51]	validation_0-logloss:0.65793
# [52]	validation_0-logloss:0.65810
# [53]	validation_0-logloss:0.65840
# [54]	validation_0-logloss:0.65835
# [55]	validation_0-logloss:0.65790
# [56]	validation_0-logloss:0.65756
# [57]	validation_0-logloss:0.65756
# [58]	validation_0-logloss:0.65786
# [59]	validation_0-logloss:0.65805
# [60]	validation_0-logloss:0.65802
# [61]	validation_0-logloss:0.65819
# [62]	validation_0-logloss:0.65844
# [63]	validation_0-logloss:0.65865
# [64]	validation_0-logloss:0.65893
# [65]	validation_0-logloss:0.65876
# [66]	validation_0-logloss:0.65887
# [67]	validation_0-logloss:0.65932
# [68]	validation_0-logloss:0.65950
# [69]	validation_0-logloss:0.65975
# [70]	validation_0-logloss:0.65973
# [71]	validation_0-logloss:0.66002
# [72]	validation_0-logloss:0.66017
# [73]	validation_0-logloss:0.66059
# [74]	validation_0-logloss:0.66083
# [75]	validation_0-logloss:0.66065
# [76]	validation_0-logloss:0.66109
# [77]	validation_0-logloss:0.66165
# [78]	validation_0-logloss:0.66171
# [79]	validation_0-logloss:0.66182
# [80]	validation_0-logloss:0.66252
# [81]	validation_0-logloss:0.66266
# [82]	validation_0-logloss:0.66264
# [83]	validation_0-logloss:0.66285
# [84]	validation_0-logloss:0.66297
# [85]	validation_0-logloss:0.66304
# [86]	validation_0-logloss:0.66260
# [87]	validation_0-logloss:0.66288
# [88]	validation_0-logloss:0.66303
# [89]	validation_0-logloss:0.66327
# [90]	validation_0-logloss:0.66354
# [91]	validation_0-logloss:0.66322
# [92]	validation_0-logloss:0.66368
# [93]	validation_0-logloss:0.66425
# [94]	validation_0-logloss:0.66443
# [95]	validation_0-logloss:0.66382
# [96]	validation_0-logloss:0.66416
# [97]	validation_0-logloss:0.66430
# [98]	validation_0-logloss:0.66396
# [99]	validation_0-logloss:0.66410
# Fold: 10 Score: 0.5584686188359296
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Overall Validation Score: 0.5578029839438179

# %%
from xgboost import XGBRFClassifier

# %%
sss = StratifiedShuffleSplit(n_splits=10, random_state=1234)

preds = []
scores = []
feature_importance_df = pd.DataFrame()
for fold, (idx_train, idx_valid) in enumerate(sss.split(X, y)):
    X_train, y_train = X.iloc[idx_train], y.iloc[idx_train]
    X_valid, y_valid = X.iloc[idx_valid], y.iloc[idx_valid]

    model = XGBRFClassifier()
    model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
    pred_valid = model.predict_proba(X_valid)[:, 1]
    fpr, tpr, _ = roc_curve(y_valid, pred_valid)
    score = auc(fpr, tpr)
    scores.append(score)

    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = X.columns
    fold_importance_df["importance"] = model.feature_importances_
    fold_importance_df["fold"] = fold + 1
    feature_importance_df = pd.concat(
        [feature_importance_df, fold_importance_df], axis=0
    )

    print(f"Fold: {fold + 1} Score: {score}" "\n")
    print("||" * 40, "\n")

    test_preds = model.predict_proba(X_test)[:, 1]
    preds.append(test_preds)

print(f"Overall Validation Score: {np.mean(scores)}")
# Out:
# [01:24:08] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.64881
# Fold: 1 Score: 0.5755309429836631
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:13] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.64848
# Fold: 2 Score: 0.5749350554039192
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:18] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.64907
# Fold: 3 Score: 0.5700003993269722
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:23] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.65006
# Fold: 4 Score: 0.5706710258062357
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:27] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.65034
# Fold: 5 Score: 0.5630916379852767
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:32] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.65048
# Fold: 6 Score: 0.5601509186139253
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:37] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.65002
# Fold: 7 Score: 0.566472561380333
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:42] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.64863
# Fold: 8 Score: 0.5722756187139728
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:47] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.64944
# Fold: 9 Score: 0.570083907230948
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# [01:24:52] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.64894
# Fold: 10 Score: 0.5730107311029303
#
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
#
# Overall Validation Score: 0.5696222798548176
